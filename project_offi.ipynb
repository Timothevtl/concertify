# %% [markdown]
# # Webscrapping Project : Concerts Map

# %% [markdown]
# ## Webscrapping concerts data from the website offi

# %% [markdown]
# ### Imports

# %%
import re 
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

from IPython.display import display
from geopy.geocoders import Nominatim
import folium
import time

from IPython.core.display import display, HTML
from pyngrok import ngrok

# %% [markdown]
# ### Extracting data

# %%
url        = "https://www.offi.fr/concerts/prochainement.html"
requesting = requests.get(url)
soup       = BeautifulSoup(requesting.content, "html.parser")

# %%
concerts_layout=soup.find(class_='mini-fiche-container populaire-layout') # Un layout avec l'ensemble des informations sur les concerts dans des fiches

concerts =[]

for concert in concerts_layout.find_all(class_='column'):
    title = concert.find('span', itemprop='name').get_text(strip=True)
    location = concert.find(class_='event-place pt-2').get_text(strip=True)
    date = concert.find('b').get_text(strip=True)
    genre = [tag.text.strip() for tag in concert.find_all('span', class_='has-border item-info')]
    url = concert.find(itemprop='url')['href']
    concerts.append({"title": title, "location": location, "date": date, "genre": genre, "url": url})
    

print("Nombre de concerts : ", len(concerts),"\n")
for concert in concerts:
    print (concert)
# Out:
# Nombre de concerts :  100
#
# {'title': 'Boudchart', 'location': "L'Olympia", 'date': 'Lundi 1er Janvier : 16h00, 20h30, Mardi 2 Janvier : 20h30', 'genre': ['Oriental', 'Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/boudchart-2410651.html'}
# {'title': 'Umberto Tozzi', 'location': "L'Olympia", 'date': 'Dimanche 7 Janvier : 20h00', 'genre': ['Variété internationale', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/umberto-tozzi-2335509.html'}
# {'title': 'The Musical Story of Elvis', 'location': "L'Olympia", 'date': 'Lundi 8 Janvier : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/the-musical-story-of-elvis-2311439.html'}
# {'title': 'Kery James', 'location': 'Salle Pleyel', 'date': 'Mercredi 10 Janvier : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/kery-james-2331357.html'}
# {'title': 'Louis Bertignac', 'location': 'Salle Pleyel', 'date': 'Samedi 13 Janvier : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/louis-bertignac-2292568.html'}
# {'title': 'Jay Chou', 'location': 'Paris La Défense Arena', 'date': 'Samedi 13 Janvier : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/u-arena-6551/jay-chou-2398270.html'}
# {'title': 'Hugues Aufray', 'location': "L'Olympia", 'date': 'Dimanche 14 Janvier : 20h00', 'genre': ['Chanson française', 'Chanson'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/hugues-aufray-2335510.html'}
# {'title': 'One Night of Queen', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mardi 16 Janvier : 20h00', 'genre': ['Rock', 'Pop / Rock', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/one-night-of-queen-2328021.html'}
# {'title': 'Slowdive', 'location': 'La Cigale', 'date': 'Mercredi 17 Janvier : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/slowdive-2411978.html'}
# {'title': 'Simple Plan', 'location': 'Le Bataclan', 'date': 'Jeudi 18 Janvier : 19h00, Vendredi 19 Janvier : 19h00, Samedi 20 Janvier : 19h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/simple-plan-2331533.html'}
# {'title': 'Fish Leong', 'location': 'Salle Pleyel', 'date': 'Jeudi 18 Janvier : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/fish-leong-2409417.html'}
# {'title': 'Camille Lellouche', 'location': 'Salle Pleyel', 'date': 'Vendredi 19 Janvier : 20h00, Samedi 20 Janvier : 20h00', 'genre': ['Chanson française', 'Chanson', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/camille-lellouche-2280489.html'}
# {'title': 'Elsa Esnoult', 'location': 'Les Folies Bergère', 'date': 'Samedi 20 Janvier : 20h00', 'genre': ['Chanson française', 'Chanson', '25-60\xa0€'], 'url': 'https://www.offi.fr/concerts/les-folies-bergere-2331/elsa-esnoult-2369166.html'}
# {'title': 'Dorian Electra', 'location': 'La Cigale', 'date': 'Lundi 22 Janvier : 20h00', 'genre': ['Électro'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/dorian-electra-2411979.html'}
# {'title': 'Tesseract', 'location': 'Le Bataclan', 'date': 'Mardi 23 Janvier : 19h00', 'genre': ['Metal', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/tesseract-2331534.html'}
# {'title': 'Prince Waly', 'location': "L'Olympia", 'date': 'Mardi 23 Janvier : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/prince-waly-2165930.html'}
# {'title': 'Eagle-Eye Cherry', 'location': 'La Cigale', 'date': 'Mardi 23 Janvier : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/eagle-eye-cherry-2411980.html'}
# {'title': 'Architects', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mercredi 24 Janvier : 19h00', 'genre': ['Metal', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/architects-2409436.html'}
# {'title': 'Charlotte Cardin', 'location': "L'Olympia", 'date': 'Mercredi 24 Janvier : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/charlotte-cardin-2335511.html'}
# {'title': 'Blick Bassy', 'location': 'La Cigale', 'date': 'Mercredi 24 Janvier : 20h00', 'genre': ['Soul', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/blick-bassy-2411981.html'}
# {'title': 'Tito Nieves', 'location': 'Le Bataclan', 'date': 'Mercredi 24 Janvier : 20h00', 'genre': ['Salsa', 'Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/tito-nieves-2416242.html'}
# {'title': 'Les Rootsriders', 'location': "L'Olympia", 'date': 'Jeudi 25 Janvier : 20h00', 'genre': ['Reggae', 'Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/les-rootsriders-2335512.html'}
# {'title': 'The Rabeats', 'location': "L'Olympia", 'date': 'Vendredi 26 Janvier : 20h00, Samedi 27 Janvier : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/the-rabeats-2019794.html'}
# {'title': 'Four Tet', 'location': 'Le Zénith Paris - La Villette', 'date': 'Samedi 27 Janvier : 18h00', 'genre': ['Électro'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/four-tet-2409437.html'}
# {'title': 'Yuzmv', 'location': 'Le Trianon', 'date': 'Samedi 27 Janvier : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/yuzmv-2414667.html'}
# {'title': 'With U2 Day', 'location': "L'Olympia", 'date': 'Dimanche 28 Janvier : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/with-u2-day-2335513.html'}
# {'title': 'Salvatore Adamo', 'location': 'Le Grand Rex', 'date': 'Lundi 29 Janvier : 20h00', 'genre': ['Chanson française', 'Chanson'], 'url': 'https://www.offi.fr/concerts/le-rex-3071/salvatore-adamo-2414735.html'}
# {'title': 'Souad Massi', 'location': 'Les Folies Bergère', 'date': 'Mardi 30 Janvier : 20h00', 'genre': ['Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/les-folies-bergere-2331/souad-massi-2215291.html'}
# {'title': 'Beast in Black - Gloryhammer', 'location': "L'Olympia", 'date': 'Mardi 30 Janvier : 20h00', 'genre': ['Metal', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/beast-in-black-gloryhammer-2335515.html'}
# {'title': 'Davido', 'location': 'Accor Arena', 'date': 'Mercredi 31 Janvier : 20h00', 'genre': ['Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/davido-2409379.html'}
# {'title': 'Les Visiteurs du National', 'location': 'Maison de la Radio et de la Musique', 'date': 'Mercredi 31 Janvier : 20h00', 'genre': ['Klezmer', 'Monde / Traditionnel'], 'url': 'https://www.offi.fr/concerts/maison-de-radio-france-2674/les-visiteurs-du-national-2327496.html'}
# {'title': 'Voyou', 'location': "L'Olympia", 'date': 'Mercredi 31 Janvier : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/voyou-2335516.html'}
# {'title': 'Arthur H', 'location': 'Grande Seine - La Seine Musicale', 'date': 'Jeudi 1er Février : 20h00', 'genre': ['Chanson française', 'Chanson'], 'url': 'https://www.offi.fr/concerts/grande-seine-6496/arthur-h-2323404.html'}
# {'title': 'Roshi', 'location': "L'Olympia", 'date': 'Jeudi 1er Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/roshi-2335517.html'}
# {'title': 'WhoMadeWho', 'location': 'La Cigale', 'date': 'Jeudi 1er Février : 20h00', 'genre': ['Électro pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/whomadewho-2412016.html'}
# {'title': 'Les Sheriff', 'location': 'Le Bataclan', 'date': 'Vendredi 2 Février : 19h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/les-sheriff-2416244.html'}
# {'title': 'Fakear', 'location': 'Salle Pleyel', 'date': 'Vendredi 2 Février : 19h30', 'genre': ['Électro', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/fakear-2261028.html'}
# {'title': 'Bomel', 'location': 'La Cigale', 'date': 'Vendredi 2 Février : 20h00', 'genre': ['Électro'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/bomel-2242426.html'}
# {'title': 'Nothing But Thieves', 'location': "L'Olympia", 'date': 'Vendredi 2 Février : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/nothing-but-thieves-2335518.html'}
# {'title': 'Demi Portion', 'location': 'Le Bataclan', 'date': 'Samedi 3 Février : 19h30', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/demi-portion-2416245.html'}
# {'title': 'Yvnnis', 'location': 'La Cigale', 'date': 'Samedi 3 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/yvnnis-2412021.html'}
# {'title': 'Gil Semedo', 'location': 'Le Grand Rex', 'date': 'Samedi 3 Février : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-rex-3071/gil-semedo-2414736.html'}
# {'title': 'Peyton Parrish', 'location': 'Le Bataclan', 'date': 'Dimanche 4 Février : 20h00', 'genre': ['Metal', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/peyton-parrish-2416246.html'}
# {'title': 'Bad Omens', 'location': 'Salle Pleyel', 'date': 'Mardi 6 Février : 20h00', 'genre': ['Metal', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/bad-omens-2302163.html'}
# {'title': 'The Australian Pink Floyd Show', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mardi 6 Février : 20h00', 'genre': ['Rock', 'Pop / Rock', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/the-australian-pink-floyd-show-2326897.html'}
# {'title': 'Chien noir', 'location': 'La Cigale', 'date': 'Mardi 6 Février : 20h00', 'genre': ['Chanson française', 'Chanson'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/chien-noir-2412261.html'}
# {'title': 'Molécule', 'location': "L'Olympia", 'date': 'Mercredi 7 Février : 20h00', 'genre': ['Électro'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/molecule-2335519.html'}
# {'title': 'Souffrance', 'location': 'La Cigale', 'date': 'Mercredi 7 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/souffrance-2412262.html'}
# {'title': 'Loud', 'location': "L'Olympia", 'date': 'Jeudi 8 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/loud-2335520.html'}
# {'title': 'Sauvan', 'location': 'La Cigale', 'date': 'Jeudi 8 Février : 20h00', 'genre': ['Électro pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/sauvan-2412263.html'}
# {'title': 'James Arthur', 'location': 'Le Trianon', 'date': 'Jeudi 8 Février : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/james-arthur-2414669.html'}
# {'title': 'Apashe', 'location': "L'Olympia", 'date': 'Vendredi 9 Février : 20h00', 'genre': ['Électro'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/apashe-2410654.html'}
# {'title': 'Swing', 'location': 'La Cigale', 'date': 'Vendredi 9 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/swing-2413120.html'}
# {'title': 'Shkoon', 'location': 'Le Bataclan', 'date': 'Samedi 10 Février : 19h00', 'genre': ['Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/shkoon-2416247.html'}
# {'title': 'Kim Wilde', 'location': "L'Olympia", 'date': 'Samedi 10 Février : 20h00', 'genre': ['Pop', 'Pop / Rock', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/kim-wilde-2335521.html'}
# {'title': 'Salvatore Adamo', 'location': "L'Olympia", 'date': 'Dimanche 11 Février : 20h00', 'genre': ['Chanson française', 'Chanson'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/salvatore-adamo-2335522.html'}
# {'title': 'Masego', 'location': 'Le Zénith Paris - La Villette', 'date': 'Dimanche 11 Février : 20h00', 'genre': ['RnB', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/masego-2409438.html'}
# {'title': 'Laura Pausini', 'location': 'Accor Arena', 'date': 'Lundi 12 Février : 20h00', 'genre': ['Variété internationale', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/laura-pausini-2247825.html'}
# {'title': 'Reneé Rapp', 'location': "L'Olympia", 'date': 'Mardi 13 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/renee-rapp-2335523.html'}
# {'title': 'Franglish', 'location': 'Accor Arena', 'date': 'Mardi 13 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/franglish-2409380.html'}
# {'title': 'Maisie Peters', 'location': "L'Olympia", 'date': 'Mercredi 14 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/maisie-peters-2410655.html'}
# {'title': 'Mike Oldfield', 'location': 'Salle Pleyel', 'date': 'Jeudi 15 Février : 20h00', 'genre': ['Folk', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/salle-pleyel-3159/mike-oldfield-2409418.html'}
# {'title': 'Dadju & Tayc', 'location': 'Accor Arena', 'date': 'Jeudi 15 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/dadju-tayc-2409381.html'}
# {'title': 'Jeanne Mas', 'location': 'Casino de Paris', 'date': 'Jeudi 15 Février : 20h00, Vendredi 16 Février : 20h00, Samedi 17 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/casino-de-paris-1638/jeanne-mas-2414752.html'}
# {'title': 'Maes', 'location': 'Accor Arena', 'date': 'Vendredi 16 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/maes-2409383.html'}
# {'title': 'Orchestral Manoeuvres in the Dark', 'location': 'La Cigale', 'date': 'Vendredi 16 Février : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/orchestral-manoeuvres-in-the-dark-2413121.html'}
# {'title': 'Bâtiment B', 'location': 'Grande salle Pierre Boulez - Philharmonie de Paris', 'date': 'Samedi 17 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/grande-salle-6005/batiment-b-2310487.html'}
# {'title': 'Noah Kahan', 'location': "L'Olympia", 'date': 'Samedi 17 Février : 20h00', 'genre': ['Folk', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/noah-kahan-2335524.html'}
# {'title': 'Kaaris', 'location': 'Accor Arena', 'date': 'Samedi 17 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/kaaris-2409384.html'}
# {'title': 'Oxmo Puccino', 'location': 'Grande salle Pierre Boulez - Philharmonie de Paris', 'date': 'Dimanche 18 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/grande-salle-6005/oxmo-puccino-2310488.html'}
# {'title': 'Miles Kane', 'location': 'La Cigale', 'date': 'Lundi 19 Février : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/miles-kane-2413122.html'}
# {'title': 'RSKO', 'location': 'La Cigale', 'date': 'Mercredi 21 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/rsko-2413123.html'}
# {'title': 'Enter Shikari', 'location': 'Le Trianon', 'date': 'Mercredi 21 Février : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/enter-shikari-2414673.html'}
# {'title': 'Majid Jordan', 'location': 'Le Bataclan', 'date': 'Mercredi 21 Février : 20h00', 'genre': ['RnB', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/majid-jordan-2416248.html'}
# {'title': 'Yamê', 'location': 'Le Trianon', 'date': 'Jeudi 22 Février : 20h00', 'genre': ['Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/yame-2414676.html'}
# {'title': 'Ziak', 'location': 'Le Zénith Paris - La Villette', 'date': 'Vendredi 23 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/ziak-2331504.html'}
# {'title': '6lack', 'location': 'Le Bataclan', 'date': 'Vendredi 23 Février : 20h00', 'genre': ['Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/6lack-2416249.html'}
# {'title': 'Frank Carter & The Rattlesnakes', 'location': 'Le Bataclan', 'date': 'Samedi 24 Février : 19h30', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/frank-carter-the-rattlesnakes-2416250.html'}
# {'title': 'Josman', 'location': 'Accor Arena', 'date': 'Samedi 24 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/josman-2121614.html'}
# {'title': 'Zara Larsson', 'location': 'Le Trianon', 'date': 'Samedi 24 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/zara-larsson-2414677.html'}
# {'title': 'Calema', 'location': 'Le Dôme de Paris - Palais des Sports', 'date': 'Samedi 24 Février : 20h00', 'genre': ['RnB', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-des-sports-2911/calema-2334388.html'}
# {'title': 'Stephen Sanchez', 'location': 'Le Trianon', 'date': 'Dimanche 25 Février : 19h30', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/stephen-sanchez-2414678.html'}
# {'title': 'Kim Petras', 'location': "L'Olympia", 'date': 'Dimanche 25 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/kim-petras-2335525.html'}
# {'title': 'Jason Derulo', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mardi 27 Février : 19h00', 'genre': ['RnB', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/jason-derulo-2409440.html'}
# {'title': 'IAM', 'location': 'Le Bataclan', 'date': 'Mardi 27 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-bataclan-1526/iam-2331347.html'}
# {'title': 'Stephan Eicher', 'location': "L'Olympia", 'date': 'Mardi 27 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/stephan-eicher-2335526.html'}
# {'title': 'Later.', 'location': 'La Cigale', 'date': 'Mardi 27 Février : 20h00', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/later-2413125.html'}
# {'title': 'IAM', 'location': 'La Cigale', 'date': 'Mercredi 28 Février : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/iam-2331345.html'}
# {'title': 'Stephan Eicher', 'location': "L'Olympia", 'date': 'Mercredi 28 Février : 20h00, Jeudi 29 Février : 20h00', 'genre': ['Pop', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/stephan-eicher-2335527.html'}
# {'title': 'James Blunt', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mercredi 28 Février : 20h00', 'genre': ['Pop', 'Pop / Rock', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/james-blunt-2348157.html'}
# {'title': 'Kalika', 'location': 'Le Trianon', 'date': 'Jeudi 29 Février : 19h30', 'genre': ['Pop / Rock'], 'url': 'https://www.offi.fr/concerts/theatre-trianon-3299/kalika-2331460.html'}
# {'title': 'Guy2Bezbar', 'location': 'Le Zénith Paris - La Villette', 'date': 'Jeudi 29 Février : 20h00', 'genre': ['Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/guy2bezbar-2409441.html'}
# {'title': 'Slimane', 'location': 'Accor Arena', 'date': 'Vendredi 1er Mars : 20h00', 'genre': ['Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/slimane-2235244.html'}
# {'title': 'The 1975', 'location': 'Le Zénith Paris - La Villette', 'date': 'Vendredi 1er Mars : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/the-1975-2409442.html'}
# {'title': 'Slift', 'location': 'La Cigale', 'date': 'Vendredi 1er Mars : 20h00', 'genre': ['Rock', 'Pop / Rock'], 'url': 'https://www.offi.fr/concerts/la-cigale-1805/slift-2413126.html'}
# {'title': 'Superpoze, Bertrand Belin et Marie-Sophie Ferdane', 'location': 'Théâtre du Rond-Point', 'date': 'Samedi 2 Mars : 19h30', 'genre': ['Pop / Rock', '31,5\xa0€'], 'url': 'https://www.offi.fr/concerts/theatre-du-rond-point-3085/superpoze-bertrand-belin-et-marie-sophie-ferdane-2302016.html'}
# {'title': 'Kaaris', 'location': 'Accor Arena', 'date': 'Samedi 2 Mars : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/kaaris-2409385.html'}
# {'title': 'Ronisia', 'location': 'Le Zénith Paris - La Villette', 'date': 'Samedi 2 Mars : 20h00', 'genre': ['RnB', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/le-zenith-3401/ronisia-2409443.html'}
# {'title': 'IAM', 'location': "L'Olympia", 'date': 'Dimanche 3 Mars : 20h00', 'genre': ['Rap', 'Musiques urbaines'], 'url': 'https://www.offi.fr/concerts/lolympia-2874/iam-2331348.html'}
# {'title': 'Depeche Mode', 'location': 'Accor Arena', 'date': 'Dimanche 3 Mars : 20h00, Mardi 5 Mars : 20h00', 'genre': ['Électro pop', 'Pop / Rock', 'Choix de la rédaction'], 'url': 'https://www.offi.fr/concerts/palais-omnisports-de-paris-bercy-2913/depeche-mode-2331482.html'}

# %% [markdown]
# ### Map of concerts

# %%
def geocode_location(location):
    geolocator = Nominatim(user_agent="geoapiExercises")
    try:
        loc = geolocator.geocode(location)
        return (loc.latitude, loc.longitude)
    except:
        return None

# Geocode each concert location
for concert in concerts:
    coords = geocode_location(concert['location'])
    if coords:
        concert['coords'] = coords
    else:
        concert['coords'] = (0, 0)  # Default coords, adjust as necessary

# Group concerts by location
concerts_by_location = {}
for concert in concerts:
    key = concert['coords']
    if key not in concerts_by_location:
        concerts_by_location[key] = {'name': concert['location'], 'concerts': []}
    concerts_by_location[key]['concerts'].append(concert)

# Create a map and add markers
map = folium.Map(location=[48.8566, 2.3522], zoom_start=12)  # Centered on Paris

for location, data in concerts_by_location.items():
    location_name = data['name']
    concerts_at_location = data['concerts']

    popup_content = f"<h3>{location_name}</h3><ul>"
    for concert in concerts_at_location:
        # Create a hyperlink for each concert
        concert_link = f"<a href='{concert['url']}' target='_blank'>{concert['title']}</a>"
        popup_content += f"<li>{concert_link} - {concert['date']}</li>"
    popup_content += '</ul>'

    # Use BeautifulSoup to format HTML in the popup
    soup = BeautifulSoup(popup_content, 'html.parser')
    popup_content = str(soup)

    folium.Marker(
        location=location,
        popup=folium.Popup(popup_content, max_width=300),
        tooltip=location_name
    ).add_to(map)

# Add layer control and display the map
folium.LayerControl().add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_991c63507511e242635fc96bc3e68ea0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_991c63507511e242635fc96bc3e68ea0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_991c63507511e242635fc96bc3e68ea0 = L.map(
#                 &quot;map_991c63507511e242635fc96bc3e68ea0&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa5b74bfa4584c43c2c021e3343ad052 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_991c63507511e242635fc96bc3e68ea0);
#
#
#             var marker_d1dccef7db63236f2af693973f077e16 = L.marker(
#                 [43.1377968, 5.893346584234303],
#                 {}
#             ).addTo(map_991c63507511e242635fc96bc3e68ea0);
#
#
#         var popup_d3603083c0dd548b19793a6cfd0e8529 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a7fb12a53a1d39da8174ea3cd558eb6f = $(`&lt;div id=&quot;html_a7fb12a53a1d39da8174ea3cd558eb6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h3&gt;L&#x27;Olympia&lt;/h3&gt;&lt;ul&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/boudchart-2410651.html&quot; target=&quot;_blank&quot;&gt;Boudchart&lt;/a&gt; - Lundi 1er Janvier : 16h00, 20h30, Mardi 2 Janvier : 20h30&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/umberto-tozzi-2335509.html&quot; target=&quot;_blank&quot;&gt;Umberto Tozzi&lt;/a&gt; - Dimanche 7 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/the-musical-story-of-elvis-2311439.html&quot; target=&quot;_blank&quot;&gt;The Musical Story of Elvis&lt;/a&gt; - Lundi 8 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/hugues-aufray-2335510.html&quot; target=&quot;_blank&quot;&gt;Hugues Aufray&lt;/a&gt; - Dimanche 14 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/prince-waly-2165930.html&quot; target=&quot;_blank&quot;&gt;Prince Waly&lt;/a&gt; - Mardi 23 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/charlotte-cardin-2335511.html&quot; target=&quot;_blank&quot;&gt;Charlotte Cardin&lt;/a&gt; - Mercredi 24 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/les-rootsriders-2335512.html&quot; target=&quot;_blank&quot;&gt;Les Rootsriders&lt;/a&gt; - Jeudi 25 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/the-rabeats-2019794.html&quot; target=&quot;_blank&quot;&gt;The Rabeats&lt;/a&gt; - Vendredi 26 Janvier : 20h00, Samedi 27 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/with-u2-day-2335513.html&quot; target=&quot;_blank&quot;&gt;With U2 Day&lt;/a&gt; - Dimanche 28 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/beast-in-black-gloryhammer-2335515.html&quot; target=&quot;_blank&quot;&gt;Beast in Black - Gloryhammer&lt;/a&gt; - Mardi 30 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/voyou-2335516.html&quot; target=&quot;_blank&quot;&gt;Voyou&lt;/a&gt; - Mercredi 31 Janvier : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/roshi-2335517.html&quot; target=&quot;_blank&quot;&gt;Roshi&lt;/a&gt; - Jeudi 1er Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/nothing-but-thieves-2335518.html&quot; target=&quot;_blank&quot;&gt;Nothing But Thieves&lt;/a&gt; - Vendredi 2 Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/molecule-2335519.html&quot; target=&quot;_blank&quot;&gt;Molécule&lt;/a&gt; - Mercredi 7 Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/loud-2335520.html&quot; target=&quot;_blank&quot;&gt;Loud&lt;/a&gt; - Jeudi 8 Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/apashe-2410654.html&quot; target=&quot;_blank&quot;&gt;Apashe&lt;/a&gt; - Vendredi 9 Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/kim-wilde-2335521.html&quot; target=&quot;_blank&quot;&gt;Kim Wilde&lt;/a&gt; - Samedi 10 Février : 20h00&lt;/li&gt;&lt;li&gt;&lt;a href=&quot;https://www.offi.fr/concerts/lolympia-2874/salvatore-adamo-2335522.html&quot; target=&quot;_blank&quot;&gt;Salvatore Adamo&lt;/a&gt; - Dimanche 11 Février : 20h00&lt;/li&gt;&lt;li&

# %% [markdown]
# Un screen de la map est disponible sur le github https://github.com/Timothevtl/concertify

# %% [markdown]
# #### Save the map in html

# %%
# Save the map as an HTML file
map.save("templates/concert_map.html")

# %% [markdown]
# ### API

# %% [markdown]
# app = Flask(__name__)
#
# @app.route('/')
# def index():
#     return render_template('concert_map.html')
#
# @app.route('/api/concerts/<float:lat>/<float:lon>')
# def get_concerts_at_location(lat, lon):
#     concerts_at_location = []
#     for concert in concerts:
#         if concert['coords'] == (lat, lon):
#             concerts_at_location.append({'title': concert['title'], 'date': concert['date']})
#     return jsonify(concerts_at_location)
#
# if __name__ == '__main__':
#     app.run()

# %% [markdown]
# #### Update concerts data in flask app

# %%
# %run app.py
# Out:
# {'title': 'Boris Grebenshchikov', 'location': 'Le Trianon', 'date': 'Samedi 23 Décembre : 19h00'}
# {'title': 'Boudchart', 'location': "L'Olympia", 'date': 'Lundi 1er Janvier : 16h00, 20h30, Mardi 2 Janvier : 20h30'}
# {'title': 'Umberto Tozzi', 'location': "L'Olympia", 'date': 'Dimanche 7 Janvier : 20h00'}
# {'title': 'The Musical Story of Elvis', 'location': "L'Olympia", 'date': 'Lundi 8 Janvier : 20h00'}
# {'title': 'Kery James', 'location': 'Salle Pleyel', 'date': 'Mercredi 10 Janvier : 20h00'}
# {'title': 'Louis Bertignac', 'location': 'Salle Pleyel', 'date': 'Samedi 13 Janvier : 20h00'}
# {'title': 'Jay Chou', 'location': 'Paris La Défense Arena', 'date': 'Samedi 13 Janvier : 20h00'}
# {'title': 'Hugues Aufray', 'location': "L'Olympia", 'date': 'Dimanche 14 Janvier : 20h00'}
# {'title': 'One Night of Queen', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mar 16 Janvier : 20h00'}
# {'title': 'Slowdive', 'location': 'La Cigale', 'date': 'Mercredi 17 Janvier : 20h00'}
# {'title': 'Simple Plan', 'location': 'Le Bataclan', 'date': 'Jeudi 18 Janvier : 19h00, Vendredi 19 Janvier : 19h00, Samedi 20 Janvier : 19h00'}
# {'title': 'Fish Leong', 'location': 'Salle Pleyel', 'date': 'Jeudi 18 Janvier : 20h00'}
# {'title': 'Camille Lellouche', 'location': 'Salle Pleyel', 'date': 'Vendredi 19 Janvier : 20h00, Samedi 20 Janvier : 20h00'}
# {'title': 'Elsa Esnoult', 'location': 'Les Folies Bergère', 'date': 'Samedi 20 Janvier : 20h00'}
# {'title': 'Dorian Electra', 'location': 'La Cigale', 'date': 'Lundi 22 Janvier : 20h00'}
# {'title': 'Tesseract', 'location': 'Le Bataclan', 'date': 'Mardi 23 Janvier : 19h00'}
# {'title': 'Prince Waly', 'location': "L'Olympia", 'date': 'Mardi 23 Janvier : 20h00'}
# {'title': 'Eagle-Eye Cherry', 'location': 'La Cigale', 'date': 'Mardi 23 Janvier : 20h00'}
# {'title': 'Architects', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mer 24 Janvier : 19h00'}
# {'title': 'Charlotte Cardin', 'location': "L'Olympia", 'date': 'Mercredi 24 Janvier : 20h00'}
# {'title': 'Blick Bassy', 'location': 'La Cigale', 'date': 'Mercredi 24 Janvier : 20h00'}
# {'title': 'Tito Nieves', 'location': 'Le Bataclan', 'date': 'Mercredi 24 Janvier : 20h00'}
# {'title': 'Les Rootsriders', 'location': "L'Olympia", 'date': 'Jeudi 25 Janvier : 20h00'}
# {'title': 'The Rabeats', 'location': "L'Olympia", 'date': 'Vendredi 26 Janvier : 20h00, Samedi 27 Janvier : 20h00'}
# {'title': 'Four Tet', 'location': 'Le Zénith Paris - La Villette', 'date': 'Sam 27 Janvier : 18h00'}
# {'title': 'Yuzmv', 'location': 'Le Trianon', 'date': 'Samedi 27 Janvier : 20h00'}
# {'title': 'With U2 Day', 'location': "L'Olympia", 'date': 'Dimanche 28 Janvier : 20h00'}
# {'title': 'Salvatore Adamo', 'location': 'Le Grand Rex', 'date': 'Lundi 29 Janvier : 20h00'}
# {'title': 'Souad Massi', 'location': 'Les Folies Bergère', 'date': 'Mardi 30 Janvier : 20h00'}
# {'title': 'Beast in Black - Gloryhammer', 'location': "L'Olympia", 'date': 'Mardi 30 Janvier : 20h00'}
# {'title': 'Davido', 'location': 'Accor Arena', 'date': 'Mercredi 31 Janvier : 20h00'}
# {'title': 'Les Visiteurs du National', 'location': 'Maison de la Radio et de la Musique', 'date': 'Mercredi 31 Janvier : 20h00'}
# {'title': 'Voyou', 'location': "L'Olympia", 'date': 'Mercredi 31 Janvier : 20h00'}
# {'title': 'Arthur H', 'location': 'Grande Seine - La Seine Musicale', 'date': 'Jeudi 1er Février : 20h00'}
# {'title': 'Roshi', 'location': "L'Olympia", 'date': 'Jeudi 1er Février : 20h00'}
# {'title': 'WhoMadeWho', 'location': 'La Cigale', 'date': 'Jeudi 1er Février : 20h00'}
# {'title': 'Les Sheriff', 'location': 'Le Bataclan', 'date': 'Vendredi 2 Février : 19h00'}
# {'title': 'Fakear', 'location': 'Salle Pleyel', 'date': 'Vendredi 2 Février : 19h30'}
# {'title': 'Bomel', 'location': 'La Cigale', 'date': 'Vendredi 2 Février : 20h00'}
# {'title': 'Nothing But Thieves', 'location': "L'Olympia", 'date': 'Vendredi 2 Février : 20h00'}
# {'title': 'Demi Portion', 'location': 'Le Bataclan', 'date': 'Samedi 3 Février : 19h30'}
# {'title': 'Yvnnis', 'location': 'La Cigale', 'date': 'Samedi 3 Février : 20h00'}
# {'title': 'Gil Semedo', 'location': 'Le Grand Rex', 'date': 'Samedi 3 Février : 20h00'}
# {'title': 'Peyton Parrish', 'location': 'Le Bataclan', 'date': 'Dimanche 4 Février : 20h00'}
# {'title': 'Bad Omens', 'location': 'Salle Pleyel', 'date': 'Mardi 6 Février : 20h00'}
# {'title': 'The Australian Pink Floyd Show', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mar 6 Février : 20h00'}
# {'title': 'Chien noir', 'location': 'La Cigale', 'date': 'Mardi 6 Février : 20h00'}
# {'title': 'Molécule', 'location': "L'Olympia", 'date': 'Mercredi 7 Février : 20h00'}
# {'title': 'Souffrance', 'location': 'La Cigale', 'date': 'Mercredi 7 Février : 20h00'}
# {'title': 'Loud', 'location': "L'Olympia", 'date': 'Jeudi 8 Février : 20h00'}
# {'title': 'Sauvan', 'location': 'La Cigale', 'date': 'Jeudi 8 Février : 20h00'}
# {'title': 'James Arthur', 'location': 'Le Trianon', 'date': 'Jeudi 8 Février : 20h00'}
# {'title': 'Apashe', 'location': "L'Olympia", 'date': 'Vendredi 9 Février : 20h00'}
# {'title': 'Swing', 'location': 'La Cigale', 'date': 'Vendredi 9 Février : 20h00'}
# {'title': 'Shkoon', 'location': 'Le Bataclan', 'date': 'Samedi 10 Février : 19h00'}
# {'title': 'Kim Wilde', 'location': "L'Olympia", 'date': 'Samedi 10 Février : 20h00'}
# {'title': 'Salvatore Adamo', 'location': "L'Olympia", 'date': 'Dimanche 11 Février : 20h00'}
# {'title': 'Masego', 'location': 'Le Zénith Paris - La Villette', 'date': 'Dim 11 Février : 20h00'}
# {'title': 'Laura Pausini', 'location': 'Accor Arena', 'date': 'Lundi 12 Février : 20h00'}
# {'title': 'Reneé Rapp', 'location': "L'Olympia", 'date': 'Mardi 13 Février : 20h00'}
# {'title': 'Franglish', 'location': 'Accor Arena', 'date': 'Mardi 13 Février : 20h00'}
# {'title': 'Maisie Peters', 'location': "L'Olympia", 'date': 'Mercredi 14 Février : 20h00'}
# {'title': 'Mike Oldfield', 'location': 'Salle Pleyel', 'date': 'Jeudi 15 Février : 20h00'}
# {'title': 'Dadju & Tayc', 'location': 'Accor Arena', 'date': 'Jeudi 15 Février : 20h00'}
# {'title': 'Jeanne Mas', 'location': 'Casino de Paris', 'date': 'Jeudi 15 Février : 20h00, Vendredi 16 Février : 20h00, Samedi 17 Février : 20h00'}
# {'title': 'Maes', 'location': 'Accor Arena', 'date': 'Vendredi 16 Février : 20h00'}
# {'title': 'Orchestral Manoeuvres in the Dark', 'location': 'La Cigale', 'date': 'Vendredi 16 Février : 20h00'}
# {'title': 'Bâtiment B', 'location': 'Grande salle Pierre Boulez - Philharmonie de Paris', 'date': 'Samedi 17 Février : 20h00'}
# {'title': 'Noah Kahan', 'location': "L'Olympia", 'date': 'Samedi 17 Février : 20h00'}
# {'title': 'Kaaris', 'location': 'Accor Arena', 'date': 'Samedi 17 Février : 20h00'}
# {'title': 'Oxmo Puccino', 'location': 'Grande salle Pierre Boulez - Philharmonie de Paris', 'date': 'Dimanche 18 Février : 20h00'}
# {'title': 'Miles Kane', 'location': 'La Cigale', 'date': 'Lundi 19 Février : 20h00'}
# {'title': 'RSKO', 'location': 'La Cigale', 'date': 'Mercredi 21 Février : 20h00'}
# {'title': 'Enter Shikari', 'location': 'Le Trianon', 'date': 'Mercredi 21 Février : 20h00'}
# {'title': 'Majid Jordan', 'location': 'Le Bataclan', 'date': 'Mercredi 21 Février : 20h00'}
# {'title': 'Yamê', 'location': 'Le Trianon', 'date': 'Jeudi 22 Février : 20h00'}
# {'title': 'Ziak', 'location': 'Le Zénith Paris - La Villette', 'date': 'Ven 23 Février : 20h00'}
# {'title': '6lack', 'location': 'Le Bataclan', 'date': 'Vendredi 23 Février : 20h00'}
# {'title': 'Frank Carter & The Rattlesnakes', 'location': 'Le Bataclan', 'date': 'Samedi 24 Février : 19h30'}
# {'title': 'Josman', 'location': 'Accor Arena', 'date': 'Samedi 24 Février : 20h00'}
# {'title': 'Zara Larsson', 'location': 'Le Trianon', 'date': 'Samedi 24 Février : 20h00'}
# {'title': 'Calema', 'location': 'Le Dôme de Paris - Palais des Sports', 'date': 'Samedi 24 Février : 20h00'}
# {'title': 'Stephen Sanchez', 'location': 'Le Trianon', 'date': 'Dimanche 25 Février : 19h30'}
# {'title': 'Kim Petras', 'location': "L'Olympia", 'date': 'Dimanche 25 Février : 20h00'}
# {'title': 'Jason Derulo', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mar 27 Février : 19h00'}
# {'title': 'IAM', 'location': 'Le Bataclan', 'date': 'Mardi 27 Février : 20h00'}
# {'title': 'Stephan Eicher', 'location': "L'Olympia", 'date': 'Mardi 27 Février : 20h00'}
# {'title': 'Later.', 'location': 'La Cigale', 'date': 'Mardi 27 Février : 20h00'}
# {'title': 'IAM', 'location': 'La Cigale', 'date': 'Mercredi 28 Février : 20h00'}
# {'title': 'Stephan Eicher', 'location': "L'Olympia", 'date': 'Mercredi 28 Février : 20h00, Jeudi 29 Février : 20h00'}
# {'title': 'James Blunt', 'location': 'Le Zénith Paris - La Villette', 'date': 'Mer 28 Février : 20h00'}
# {'title': 'Kalika', 'location': 'Le Trianon', 'date': 'Jeudi 29 Février : 19h30'}
# {'title': 'Guy2Bezbar', 'location': 'Le Zénith Paris - La Villette', 'date': 'Jeu 29 Février : 20h00'}
# {'title': 'Slimane', 'location': 'Accor Arena', 'date': 'Vendredi 1er Mars : 20h00'}
# {'title': 'The 1975', 'location': 'Le Zénith Paris - La Villette', 'date': 'Ven 1er Mars : 20h00'}
# {'title': 'Slift', 'location': 'La Cigale', 'date': 'Vendredi 1er Mars : 20h00'}
# {'title': 'Superpoze, Bertrand Belin et Marie-Sophie Ferdane', 'location': 'Théâtre du Rond-Point', 'date': 'Samedi 2 Mars : 19h30'}
# {'title': 'Ronisia', 'location': 'Le Zénith Paris - La Villette', 'date': 'Sam 2 Mars : 20h00'}
# {'title': 'Kaaris', 'location': 'Accor Arena', 'date': 'Samedi 2 Mars : 20h00'}
# {'title': 'IAM', 'location': "L'Olympia", 'date': 'Dimanche 3 Mars : 20h00'}
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
#  * Restarting with windowsapi reloader

# %% [markdown]
# # Ideas for future improvement

# %% [markdown]
# Use data from apple music and then scrap favourite artists : https://medium.com/swlh/apple-music-activity-analyser-part-1-dd02173f095f

# %% [markdown]
# # Pushing updates on github repository

# %%
# !git clone https://github.com/Timothevtl/concertify.git
# Out:
# Cloning into 'concertify'...

# %%
cd concertify
# Out:
# c:\Users\Cyprien\OneDrive - De Vinci\Documents\ESILV\A5\Webscrapping\Project\concertify

# %%
# !git pull
# Out:
# Merge made by the 'ort' strategy.
#  Concertify.ipynb | 369 ++++++++++++++++++++++++++++++++++++++++---------------
#  1 file changed, 267 insertions(+), 102 deletions(-)

# %%
# !git add .
# !git commit -m "Update project.ipynb with new changes"
# !git push origin main
# Out:
# warning: in the working copy of 'project_offi.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main fe4b7e2] Update project.ipynb with new changes
#  1 file changed, 129 insertions(+), 111 deletions(-)
# To https://github.com/Timothevtl/concertify.git
#    dc73481..fe4b7e2  main -> main
